# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load CSV
df = pd.read_csv('BurnOut1.csv')

# %%
#Score Ranges
score_columns = ['Score'] + [f'Score.{i}' for i in range(1, 26)]

# %%
# List with corresponding questions
question_texts = []
for score_col in score_columns:
    score_index = df.columns.get_loc(score_col)
    question_text = df.columns[score_index - 1]
    question_texts.append(question_text)

# %%
# Replace non-numeric values with NaN and calculate the total score
df[score_columns] = df[score_columns].apply(pd.to_numeric, errors='coerce')
total_scores = df[score_columns].sum()

# %%
# Create a DataFrame question text and the total score
score_df = pd.DataFrame({'Question': question_texts, 'TotalScore': total_scores.values})

# %%
# Sort top 5 questions by total score
top_5_scores = score_df.nlargest(5, 'TotalScore')

# %%
# Plot the pie chart top 5 burnout questions
plt.figure(figsize=(12, 10))
plt.pie(top_5_scores['TotalScore'], labels=top_5_scores['Question'], autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Burnout Questions by Total Score')
plt.axis('equal') 


plt.tight_layout()
plt.show()
# Out:
# /var/folders/2m/j6ql78x14931wns3gsw7blrr0000gn/T/ipykernel_61187/3159874737.py:8: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Plot the pie chart top 5 burnout questions with total score
plt.figure(figsize=(12, 10))
plt.pie(top_5_scores['TotalScore'], labels=top_5_scores['Question'],
        autopct=lambda p: '{:.0f}'.format(p * sum(top_5_scores['TotalScore']) / 100),
        startangle=140)
plt.title('Top 5 Burnout Questions by Total Score')
plt.axis('equal') 

plt.tight_layout()
plt.show()
# Out:
# /var/folders/2m/j6ql78x14931wns3gsw7blrr0000gn/T/ipykernel_61187/2931197389.py:9: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Sort to lowest 5 questions by total score percentage
lowest_5_scores = score_df.nsmallest(5, 'TotalScore')

# Plot the pie chart for the lowest 5 burnout questions
plt.figure(figsize=(12, 10))
plt.pie(lowest_5_scores['TotalScore'], labels=lowest_5_scores['Question'], autopct='%1.1f%%', startangle=140)
plt.title('Lowest 5 Burnout Questions by Total Score')
plt.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/2m/j6ql78x14931wns3gsw7blrr0000gn/T/ipykernel_61187/3892046264.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Sort lowest 5 questions by total score count
lowest_5_scores = score_df.nsmallest(5, 'TotalScore')

# Plot the pie chart for the lowest 5 burnout questions 
plt.figure(figsize=(12, 10))
plt.pie(lowest_5_scores['TotalScore'], labels=lowest_5_scores['Question'],
        autopct=lambda p: absolute_value(p, lowest_5_scores['TotalScore']),
        startangle=140)
plt.title('Lowest 5 Burnout Questions by Total Score')
plt.axis('equal') 

plt.tight_layout()
plt.show()
# Out:
# /var/folders/2m/j6ql78x14931wns3gsw7blrr0000gn/T/ipykernel_61187/4025461309.py:9: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Plot the bar chart for the lowest 5 burnout questions
plt.figure(figsize=(10, 8))
plt.bar(lowest_5_scores['Question'], lowest_5_scores['TotalScore'], color='skyblue')
plt.xlabel('Questions')
plt.ylabel('Total Score')
plt.title('Lowest 5 Burnout Questions by Total Score')
plt.xticks(rotation=45, ha='right') 

plt.tight_layout()
plt.show()

# %%
# Define the column names for the scores
score_columns = ['Score.1', 'Score.2', 'Score.3', 'Score.4', 'Score.5',
                 'Score.6', 'Score.7', 'Score.8', 'Score.9', 'Score.10',
                 'Score.11', 'Score.12', 'Score.13', 'Score.14', 'Score.15',
                 'Score.16', 'Score.17', 'Score.18', 'Score.19', 'Score.20',
                 'Score.21', 'Score.22', 'Score.23', 'Score.24', 'Score.25']

# %%
# extract question texts
question_texts = [df.columns[df.columns.get_loc(score) - 1] for score in score_columns]

# %%
# Calculate the sum for each score column for the rows 2 through 645
scores_sum = df.iloc[1:646][score_columns].sum()

# %%
# DataFrame with the score sums and their corresponding questions
scores_df = pd.DataFrame({
    'Question': question_texts,
    'ScoreSum': scores_sum.values
})

# %%
# Sort by 'ScoreSum' to get the scores from lowest to highest
sorted_scores = scores_df.sort_values(by='ScoreSum')

# %%
# Print sorted list with the question texts
for index, row in sorted_scores.iterrows():
    print(f"{row['Question']}: {row['ScoreSum']}")
# Out:
# Client Related burnout [Are you thinking of any substance abuse (alcohol/drugs/smoking) during this period of lockdown?]: 15825.0
# Client Related burnout [Do you feel you are being supported by colleagues during the current scenario?]: 20775.0
# Client Related burnout [Do you find it fruitful while performing your work during the current scenario?]: 23950.0
# Client Related burnout [Do you have a fear of death while working in the current scenario?]: 28875.0
# Client Related burnout [Do you feel welcomed by the community because you are a health care worker and working in the current scenario?]: 29200.0
# Client Related burnout [Do you hesitate to work during this current scenario?]: 31100.0
# Work-related Burnout [Do you have enough energy for family and friends during leisure time?]: 32300.0
# Personal Burnout [How often do you feel weak and susceptible to illness?]: 32825.0
# Personal Burnout [How often do you think: â€œI canâ€™t take it anymore?]: 34030.0
# Client Related burnout [Do you feel you are being properly protected by the hospital while working in the current scenario?]: 34825.0
# Work-related Burnout [Do you feel that every working hour is tiring for you?]: 36850.0
# Work-related Burnout [Does your work frustrate you?]: 37000.0
# Client Related burnout [Do you feel depressed because of the current scenario?]: 37900.0
# Personal Burnout [How often do you feel worn out (extremely tired)?]: 38175.0
# Client Related burnout [Do you feel lock down due to the current scenario has added stress on you?]: 38225.0
# Work-related Burnout [Do you feel burnt out (complete physical or mental exhaustion) because of your work?]: 39075.0
# Personal Burnout [How often are you emotionally exhausted?]: 40775.0
# Client Related burnout [Do you have fear to catch COVID-19 infection while working in the current scenario?]: 40850.0
# Work-related Burnout [Are you exhausted in the morning at the thought of another day at work?]: 41650.0
# Work-related Burnout [Do you feel that your work is emotionally exhausting?]: 42825.0
# Client Related burnout [Do you feel that your patience is tested while working in the current scenario?]: 43600.0
# Client Related burnout [Do you feel it is hard to work in the current scenario?]: 45250.0
# Client Related burnout [Do you feel that you are giving more than what you get back while working in the current scenario?]: 46425.0
# Client Related burnout [Does it drain more of your energy to work during the current scenario?]: 47375.0
# Client Related burnout [Do you have a fear of family members catching infection because of your work exposure?]: 59000.0

# %%
# Define the column names based on the new pattern
score_columns = ['Score.1', 'Score.2', 'Score.3', 'Score.4', 'Score.5',
                 'Score.6', 'Score.7', 'Score.8', 'Score.9', 'Score.10',
                 'Score.11', 'Score.12', 'Score.13', 'Score.14', 'Score.15',
                 'Score.16', 'Score.17', 'Score.18', 'Score.19', 'Score.20',
                 'Score.21', 'Score.22', 'Score.23', 'Score.24', 'Score.25']


scores_sum = df.iloc[1:646][score_columns].sum()

print(scores_sum)

total_sum = scores_sum.sum()
print(f"The total sum of all scores is: {total_sum}")
# Out:
# Score.1     40775.0
# Score.2     34030.0
# Score.3     32825.0
# Score.4     38175.0
# Score.5     41650.0
# Score.6     36850.0
# Score.7     32300.0
# Score.8     42825.0
# Score.9     37000.0
# Score.10    39075.0
# Score.11    45250.0
# Score.12    47375.0
# Score.13    23950.0
# Score.14    46425.0
# Score.15    31100.0
# Score.16    37900.0
# Score.17    43600.0
# Score.18    38225.0
# Score.19    40850.0
# Score.20    59000.0
# Score.21    29200.0
# Score.22    15825.0
# Score.23    28875.0
# Score.24    34825.0
# Score.25    20775.0
# dtype: float64
# The total sum of all scores is: 918680.0
