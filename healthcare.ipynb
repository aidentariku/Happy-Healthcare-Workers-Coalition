# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

#import study file:

burn_out_csv_path = "./Burn Out Questionnaire cleaned.csv"

burn_out_df = pd.read_csv(burn_out_csv_path)

burn_out_df.head()
# Out:
#         Date  Age  Gender Comorbidities? Vaccination Designation  \
# 0  6/14/2021   30  Female           None  both doses       Nurse
# 1  6/14/2021   30  Female           None  both doses       Nurse
# 2  6/14/2021   40  Female           None  both doses       Nurse
# 3  6/14/2021   40  Female           None  both doses       Nurse
# 4  6/14/2021   30  Female           None  both doses       Nurse
#
#    How many hours of work per week in the current situation?  \
# 0                                                 48
# 1                                                 48
# 2                                                 73
# 3                                                 48
# 4                                                 73
#
#    Years of service?  Patients per ICU nurse Adequate PPE provided?  ...  \
# 0                  5                       1                    Yes  ...
# 1                  5                       1                     No  ...
# ...

# %%
# %pwd
# Out:
# '/Users/spicysara/Happy-Healthcare-Workers-Coalition'

# %%
# Create a bar graph comparing Years of Service vs Overall Average Score 

categories= burn_out_df["Years of service?"]
values= burn_out_df["Overall Average"]



plt.figure(figsize=(10,7))
plt.bar(categories, values, color="blue")

plt.title("Years of Service vs Overall Average Score")
plt.xlabel("Years of Service")
plt.ylabel("Overall Average Score")
plt.grid(True)

# %%
values = burn_out_df["Years of service?"]
categories = burn_out_df["Overall Average"]



plt.figure(figsize=(10,7))
plt.scatter(categories, values, color="blue", marker="o")

plt.title("Years of Service vs Overall Average Score")
plt.ylabel("Years of Service")
plt.xlabel("Overall Average Score")
plt.grid(True)
