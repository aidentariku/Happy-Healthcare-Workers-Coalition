# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

#import study file:

burn_out_csv_path = "./Burn_Out_Questionnaire_clean_NB.csv"

burn_out_csv = pd.read_csv(burn_out_csv_path)

burn_out_csv.head()
# Out:
#         Date            Age  Gender Comorbidities? Vaccination  Designation  \
# 0  6/14/2021  21 - 30 years  Female           None   both doses       Nurse
# 1  6/14/2021  21 - 30 years  Female           None   both doses       Nurse
# 2  6/14/2021  31 - 40 years  Female           None   both doses       Nurse
# 3  6/14/2021  31 - 40 years  Female           None   both doses       Nurse
# 4  6/14/2021  21 - 30 years  Female           None   both doses       Nurse
#
#   How many hours of work per week in the current situation?  \
# 0                                         < 48 hours
# 1                                         < 48 hours
# 2                                         > 72 hours
# 3                                         < 48 hours
# 4                                         > 72 hours
#
#    Patients per ICU nurse Adequate PPE provided?  \
# 0                       1                    Yes
# 1                       1                     No
# ...

# %%
# %pwd
# Out:
# '/Users/spicysara/Happy-Healthcare-Workers-Coalition'

# %%
# Create a plot comparing Years of Service vs Overall Average Score
