# %% [markdown]
# # Data Cleaning
#
# To clean the data we:
#
# 1.Eliminated columns we did not need.
#
# 2. Transformed data so we could use it.
#
# 3. Got rid of blank cells and spaces.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Change the working directory
path = r'C:\Users\AidenTariku\OneDrive - CyberRisk Alliance\Documents\Projects\Project_1\Happy-Healthcare-Workers-Coalition'
os.chdir(path)

# Read the CSV file into a DataFrame
df = pd.read_csv('Burn-Out-Questionnaire-cleaned-5.csv')

# Create a bar plot
ax = sns.barplot(x='Age', y='Overall Average', data=df, ci=None)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Burnout Score')
plt.title('Bar Plot of Age vs Burnout Score')

# Modify the x-axis labels
plt.xticks(ticks=[0, 1, 2, 3], labels=['20-30', '31-40', '41-50', '51-60'])

# Display the plot
plt.show()
# Out:
# C:\Users\AidenTariku\AppData\Local\Temp\ipykernel_18548\416205815.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='Age', y='Overall Average', data=df, ci=None)

# %% [markdown]
# # Description
#
# This bar plot shows the correlation between Age and Burnout. This graph indicates that the older someone is, the less burntout they report to be. There can be a variety of explanations for this, older workers may have more senior roles, or more comfortable roles, older people are also more experienced in their fields.
